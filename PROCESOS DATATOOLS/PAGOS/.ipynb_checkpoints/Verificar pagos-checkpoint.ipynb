# %%
import pandas as pd
import mysql.connector as mc
import matplotlib
import calendar

# %%
db = mc.connect(
  host='172.18.55.6',
  user='comandato',
  passwd='comandato123',
)
cur= db.cursor()

# %%
Dia='29'
Mes='10'
Anio='2018'
fecha_pago=Anio+Mes+Dia

# %%
# gs = goslate.Goslate()
# F_Mes=gs.translate(calendar.month_name[int(Mes)].upper(),'es')
F_Mes='OCTUBRE'

# %% [markdown]
# # OBTENER GESTION DE ASESOR

# %% [markdown]
# ### CONVENIO

# %%
querry_gestion_cuotas="""SELECT NRO_IDENTIFICACION_CLIENTE,COD_AGENTE,CAST(DATE_FORMAT(FECHA_GESTION,'%d') as UNSIGNED) as FECHA_GESTION,CONTACTO_GESTIONO,ACCION_REALIZADA,RESPUESTA_OBTENIDA,NUMERO_GESTION FROM SISTEMECUADOR_ATM.GESTION where FECHA_GESTION BETWEEN '{0}-{1}-00 00:00:00' AND '{0}-{1}-{2} 21:00:00' AND COMENTARIOS_GESTIONO LIKE '%CAMPAÑA CONVENIO%';""".format(Anio,Mes,Dia)
gestion_cuotas=pd.read_sql(querry_gestion_cuotas, con=db)

# %%
gestion_asesor_cuotas=gestion_cuotas[(gestion_cuotas['ACCION_REALIZADA']=='HACER LLAMADA') & (gestion_cuotas['CONTACTO_GESTIONO']=='CLIENTE')& (gestion_cuotas['RESPUESTA_OBTENIDA']!='YA PAGO')]

# %%
gestion_asesor_cuotas=gestion_asesor_cuotas.sort_values(by=['FECHA_GESTION'],ascending=[True])
gestion_asesor_cuotas=gestion_asesor_cuotas.drop_duplicates(['NRO_IDENTIFICACION_CLIENTE'], keep='first')
gestion_asesor_cuotas = gestion_asesor_cuotas.rename(columns={'NRO_IDENTIFICACION_CLIENTE':'IDENTIFICACION'})

# %% [markdown]
# ### CORRIENTE

# %%
querry_gestion="""SELECT NRO_IDENTIFICACION_CLIENTE,COD_AGENTE,CAST(DATE_FORMAT(FECHA_GESTION,'%d') as UNSIGNED) as FECHA_GESTION,CONTACTO_GESTIONO,ACCION_REALIZADA,RESPUESTA_OBTENIDA,NUMERO_GESTION FROM SISTEMECUADOR_ATM.GESTION where FECHA_GESTION BETWEEN '{0}-{1}-00 00:00:00' AND '{0}-{1}-{2} 21:00:00' AND COMENTARIOS_GESTIONO NOT LIKE '%CAMPAÑA CONVENIO%';""".format(Anio,Mes,Dia)
gestion=pd.read_sql(querry_gestion, con=db)

# %%
gestion_asesor=gestion[(gestion['ACCION_REALIZADA']=='HACER LLAMADA') & ((gestion['CONTACTO_GESTIONO']=='CLIENTE') | (gestion['CONTACTO_GESTIONO']=='TERC. VALIDO'))& (gestion['RESPUESTA_OBTENIDA']!='YA PAGO')]

# %%
gestion_asesor=gestion_asesor.sort_values(by=['FECHA_GESTION'],ascending=[True])

# %%
gestion_asesor=gestion_asesor.drop_duplicates(['NRO_IDENTIFICACION_CLIENTE'], keep='first')

# %%
gestion_asesor.head()
# Out:
#      NRO_IDENTIFICACION_CLIENTE COD_AGENTE  FECHA_GESTION CONTACTO_GESTIONO  \
# 0                    1308341617    D013117              1           CLIENTE
# 1024                 0922838768    D013138              1           CLIENTE
# 1025                 0800442923    D013141              1      TERC. VALIDO
# 1026                 0917969818    D013113              1      TERC. VALIDO
# 1027                 0915113955    D013141              1           CLIENTE
#
#      ACCION_REALIZADA        RESPUESTA_OBTENIDA NUMERO_GESTION
# 0       HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0989571836
# 1024    HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0967498864
# 1025    HACER LLAMADA       MENSAJE CON TERCERO      042369674
# 1026    HACER LLAMADA       MENSAJE CON TERCERO      046029059
# 1027    HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0939701024

# %% [markdown]
# # OBTENER GESTION IVR

# %%
querry_masivos="""SELECT NRO_IDENTIFICACION_CLIENTE,COD_AGENTE,CAST(DATE_FORMAT(FECHA_GESTION,'%d') as UNSIGNED) as FECHA_GESTION,CONTACTO_GESTIONO,ACCION_REALIZADA,RESPUESTA_OBTENIDA,NUMERO_GESTION FROM SISTEMECUADOR_ATM.gestion_ivr where FECHA_GESTION BETWEEN '{0}-{1}-00 00:00:00' AND '{0}-{1}-{2} 21:00:00';""".format(Anio,Mes,Dia)
gestion_masivos=pd.read_sql(querry_masivos, con=db)

# %%
gestion_ivr=gestion_masivos[(gestion_masivos['ACCION_REALIZADA']=='ENVIAR IVR') & (gestion_masivos['RESPUESTA_OBTENIDA']=='CONTESTO IVR')]

# %%
gestion_ivr.tail()
# Out:
#        NRO_IDENTIFICACION_CLIENTE COD_AGENTE  FECHA_GESTION CONTACTO_GESTIONO  \
# 348210                 0954723953     D05554             13           TITULAR
# 348211                 0950098400     D05554             13           TITULAR
# 348212                 0954723953     D05554             13           TITULAR
# 348213                 0954723953     D05554             13           TITULAR
# 348214                 0954723953     D05554             13           TITULAR
#
#        ACCION_REALIZADA RESPUESTA_OBTENIDA NUMERO_GESTION
# 348210       ENVIAR IVR       CONTESTO IVR      042566361
# 348211       ENVIAR IVR       CONTESTO IVR     0996398484
# 348212       ENVIAR IVR       CONTESTO IVR     0969930017
# 348213       ENVIAR IVR       CONTESTO IVR     0991686876
# 348214       ENVIAR IVR       CONTESTO IVR     0990271109

# %% [markdown]
# # OBTENER GESTION SMS

# %%
gestion_sms=gestion_masivos[gestion_masivos['ACCION_REALIZADA']=='ENVIAR SMS']

# %%
gestion_sms.head()
# Out:
#        NRO_IDENTIFICACION_CLIENTE COD_AGENTE  FECHA_GESTION CONTACTO_GESTIONO  \
# 119177                 1000793024     D05554              2           TITULAR
# 119178                 0101480267     D05554              2           TITULAR
# 119179                 0101602258     D05554              2           TITULAR
# 119180                 0102493996     D05554              2           TITULAR
# 119181                 0104765771     D05554              2           TITULAR
#
#        ACCION_REALIZADA RESPUESTA_OBTENIDA NUMERO_GESTION
# 119177       ENVIAR SMS        SMS ENVIADO     0999119529
# 119178       ENVIAR SMS        SMS ENVIADO     0980067184
# 119179       ENVIAR SMS        SMS ENVIADO     0990073890
# 119180       ENVIAR SMS        SMS ENVIADO     0995565745
# 119181       ENVIAR SMS        SMS ENVIADO     0997670805

# %%
gestiones=[gestion_asesor,gestion_ivr,gestion_sms]
total_gestiones=pd.concat(gestiones)

# %%
total_gestiones.head()
# Out:
#      NRO_IDENTIFICACION_CLIENTE COD_AGENTE  FECHA_GESTION CONTACTO_GESTIONO  \
# 0                    1308341617    D013117              1           CLIENTE
# 1024                 0922838768    D013138              1           CLIENTE
# 1025                 0800442923    D013141              1      TERC. VALIDO
# 1026                 0917969818    D013113              1      TERC. VALIDO
# 1027                 0915113955    D013141              1           CLIENTE
#
#      ACCION_REALIZADA        RESPUESTA_OBTENIDA NUMERO_GESTION
# 0       HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0989571836
# 1024    HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0967498864
# 1025    HACER LLAMADA       MENSAJE CON TERCERO      042369674
# 1026    HACER LLAMADA       MENSAJE CON TERCERO      046029059
# 1027    HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0939701024

# %%
total_gestiones=total_gestiones.drop_duplicates(['NRO_IDENTIFICACION_CLIENTE'], keep='first')

# %%
total_gestiones = total_gestiones.rename(columns={'NRO_IDENTIFICACION_CLIENTE':'IDENTIFICACION'})

# %%
total_gestiones.head()
# Out:
#      IDENTIFICACION COD_AGENTE  FECHA_GESTION CONTACTO_GESTIONO  \
# 0        1308341617    D013117              1           CLIENTE
# 1024     0922838768    D013138              1           CLIENTE
# 1025     0800442923    D013141              1      TERC. VALIDO
# 1026     0917969818    D013113              1      TERC. VALIDO
# 1027     0915113955    D013141              1           CLIENTE
#
#      ACCION_REALIZADA        RESPUESTA_OBTENIDA NUMERO_GESTION
# 0       HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0989571836
# 1024    HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0967498864
# 1025    HACER LLAMADA       MENSAJE CON TERCERO      042369674
# 1026    HACER LLAMADA       MENSAJE CON TERCERO      046029059
# 1027    HACER LLAMADA  INFRACTOR CUELGA LLAMADA     0939701024

# %% [markdown]
# # MULTAS ASIGNADAS

# %%
multas="""SELECT *   FROM SISTEMECUADOR_ATM.MULTAS_MENSUALES where Mes={0}""".format(Mes)
resultado_multas=pd.read_sql(multas, con=db)

# %%
resultado_multas.head()
# Out:
#        Cedula No_multa  Anio  Mes  Dia Dia_retiro  Dias_mora  Saldo Cartera  \
# 0   00042448K  4773820  2018   10    2       None        192   57.9   MENOR
# 1  1000005262  5042227  2018   10    2       None        128   19.3   MENOR
# 2  1000005262  5692266  2018   10   17       None         22  115.8   MENOR
# 3  1000112654  1605249  2018   10    2       None        935   36.6   MENOR
# 4  1000131977  1786073  2018   10    2       None        882   54.9   MENOR
#
#              Segmento                                        Descripcion  \
# 0  5. VENCIDA FASE II  DOBLE COLUMNA / ESTACIONAR SITIOS PROHIB. FUER...
# 1   4. VENCIDA FASE I        COND. QUE NO UTILICE CINTURON DE SEGURIDAD.
# 2   4. VENCIDA FASE I  DESOBEDECER SEÑALES DE TRANSITO U ORDENES DE A...
# 3          3. MENORES  COND. ESTACIONE EN SITIOS PROHIBIDOS POR LA LE...
# 4          3. MENORES  DETEN.ESTAC.VEH.LUGAR NO PERMITIDO DEJAR/RECIB...
#
#      Placa  Pago dia_pago  tipo
# 0  GRP0269  None     None  None
# 1      nan  None     None  None
# 2           None     None  None
# 3  PHY0007  None     None  None
# 4  PAA6834  None     None  None

# %%
dias_mora_multa=resultado_multas[['No_multa','Dias_mora']].copy()

# %%
dias_mora_multa = dias_mora_multa.rename(columns={'No_multa':'ID_FACTURA','Dias_mora':'DIAS_MORA'})
dias_mora_multa['ID_FACTURA']=dias_mora_multa['ID_FACTURA'].apply(int)

# %%
dias_mora_multa.head()
# Out:
#    ID_FACTURA  DIAS_MORA
# 0     4773820        192
# 1     5042227        128
# 2     5692266         22
# 3     1605249        935
# 4     1786073        882

# %% [markdown]
# # PAGOS

# %%
pago_corr={
    'ruta':'..\..\..\BASES DATATOOLS\PAGOS\\2018\\'+F_Mes+'\Sistema de cobro - '+fecha_pago+'.xlsx',
    'hoja':'PAGOS_CORRIENTE',
    'cartera':'CORRIENTE',
    'identificador':'IDENTIFICACION'
}

pago_cuot={
    'ruta':'..\..\..\BASES DATATOOLS\PAGOS\\2018\\'+F_Mes+'\\Sistema de cobro - '+fecha_pago+'.xlsx',
    'hoja':'PAGOS_CUOTA_CERO',
    'cartera':'CUOTA',
    'identificador':'ID'
}

pago_conv={
    'ruta':'..\..\..\BASES DATATOOLS\PAGOS\\2018\\'+F_Mes+'\\Sistema de cobro - '+fecha_pago+'.xlsx',
    'hoja':'PAGOS_CONVENIOS',
    'cartera':'CONVENIO',
    'identificador':'ID'
}

# %%
pagos_corr=pd.read_excel(open(pago_corr['ruta'],'rb'), sheet_name=pago_corr['hoja'], dtype={pago_corr['identificador']: str})
pagos_cuot=pd.read_excel(open(pago_cuot['ruta'],'rb'), sheet_name=pago_cuot['hoja'], dtype={pago_cuot['identificador']: str})
pagos_conv=pd.read_excel(open(pago_conv['ruta'],'rb'), sheet_name=pago_conv['hoja'], dtype={pago_conv['identificador']: str})

# %%
def agregar_ceros(base):
    ced=base['ID']
    if len(ced)==9 or len(ced)==12 :
        if ced.isdigit():
            return '0'+ced
    return ced

# %%
pagos_cuot['ID']=pagos_cuot.apply(agregar_ceros,axis=1)

# %% [markdown]
# ### CORRIENTE

# %%
def agregar_ceros2(base):
    ced=base['IDENTIFICACION']
    if len(ced)==9 or len(ced)==12 :
        if ced.isdigit():
            return '0'+ced
    return ced

# %%
pagos_corr['IDENTIFICACION']=pagos_corr.apply(agregar_ceros2,axis=1)

# %%
def tipo(base):
    casa=base['CASA_COBRO']
    if casa=='SISTEMA SALDO MENORES':
        return 'MENORES'
    else:
        return 'CORRIENTE'

# %%
pagos_corr['DIA_PAGO'] = pagos_corr['FECHA_PAGO'].dt.day
pagos_corr = pagos_corr.rename(columns={'CASA COBRO':'CASA_COBRO'})
pagos_corr['TIPO']=pagos_corr.apply(tipo,axis=1)
cruce_pag_corr=pd.merge(pagos_corr,dias_mora_multa,on=['ID_FACTURA'],how='left')
cruce_pag_corr=cruce_pag_corr[['IDENTIFICACION','ID_FACTURA','VALOR_INFRACCION','FECHA_PAGO','DIA_PAGO','TIPO','DIAS_MORA']]
cruce_pag_corr.head()
# Out:
#   IDENTIFICACION  ID_FACTURA  VALOR_INFRACCION FECHA_PAGO  DIA_PAGO     TIPO  \
# 0     0950210799     5319721             57.90 2018-09-01         1  MENORES
# 1     0918438839     5227646             57.90 2018-09-01         1  MENORES
# 2     0955180716     3423584             18.75 2018-09-01         1  MENORES
# 3     0931226344     5062092             19.30 2018-09-01         1  MENORES
# 4     0930463856     5279001             57.90 2018-09-01         1  MENORES
#
#    DIAS_MORA
# 0         39
# 1         60
# 2        455
# 3         94
# 4         47

# %% [markdown]
# ## MENORES

# %%
def identificar_pago(base):
    valor1 = base['VALOR_INFRACCION']
    valor2 = base['VALOR_PAGO_CAPITAL']
    mora = base['DIAS_MORA']
    if mora<=180:
        return valor2
    return valor1

# %%
pagos_cuot['TIPO']='CUOTA'
pagos_cuot['DIA_PAGO'] = pagos_cuot['FECHA_RE'].dt.day
pagos_cuot['MONTO_PAGO']=pagos_cuot.apply(identificar_pago,axis=1)
pagos_cuot_resumen=pagos_cuot[['ID','ID_FACTURA_INICIAL','MONTO_PAGO','FECHA_RE','DIA_PAGO','TIPO']]
pagos_cuot_resumen = pagos_cuot_resumen.rename(columns={'ID':'IDENTIFICACION','ID_FACTURA_INICIAL':'ID_FACTURA','MONTO_PAGO':'VALOR_INFRACCION','FECHA_RE':'FECHA_PAGO'})
cruce_pag_cuot=pd.merge(pagos_cuot_resumen,dias_mora_multa,on=['ID_FACTURA'],how='left')
cruce_pag_cuot.head()
# Out:
#   IDENTIFICACION  ID_FACTURA  VALOR_INFRACCION          FECHA_PAGO  DIA_PAGO  \
# 0     0917744229     5309823             36.63 2018-09-01 12:47:30         1
# 1     0924144579     3346334            112.50 2018-09-01 10:20:59         1
# 2     0924144579     3384000            112.50 2018-09-01 10:20:59         1
# 3     0924144579     3447021            112.50 2018-09-01 10:20:59         1
# 4     0924144579     3704949            112.50 2018-09-01 10:20:59         1
#
#     TIPO  DIAS_MORA
# 0  CUOTA         40
# 1  CUOTA        473
# 2  CUOTA        465
# 3  CUOTA        450
# 4  CUOTA        407

# %% [markdown]
# # CONVENIO

# %%
pagos_conv['TIPO']='CONVENIO'
pagos_conv['DIA_PAGO'] = pagos_conv['FECHA_PAGO'].dt.day

# %%
pagos_conv.head()
# Out:
#            ID  ID_CONVENIO  NRO_CUOTA_EMISION  VALOR_PAGAR_CUOTA FECHA_PAGO  \
# 0  0911992774       292221                  3               30.0 2018-09-01
# 1  0911992774       292221                  2               30.0 2018-09-01
# 2  0918876715       267479                  4               65.8 2018-09-01
# 3  0918876715       267479                  6               65.8 2018-09-01
# 4  0918876715       267479                  1               65.8 2018-09-01
#
#   FECHA_VENCIMIENTO                    CASA COBRO      TIPO  DIA_PAGO
# 0        2018-03-27  SISTEMA DE COBRO DEL ECUADOR  CONVENIO         1
# 1        2018-02-27  SISTEMA DE COBRO DEL ECUADOR  CONVENIO         1
# 2        2017-10-19  SISTEMA DE COBRO DEL ECUADOR  CONVENIO         1
# 3        2017-12-19  SISTEMA DE COBRO DEL ECUADOR  CONVENIO         1
# 4        2017-07-19  SISTEMA DE COBRO DEL ECUADOR  CONVENIO         1

# %%
pagos_conv_resumen=pagos_conv[['ID','ID_CONVENIO','VALOR_PAGAR_CUOTA','FECHA_PAGO','DIA_PAGO','TIPO','NRO_CUOTA_EMISION']]
pagos_conv_resumen = pagos_conv_resumen.rename(columns={'ID':'IDENTIFICACION','ID_CONVENIO':'ID_FACTURA','VALOR_PAGAR_CUOTA':'VALOR_INFRACCION','NRO_CUOTA_EMISION':'DIAS_MORA'})

cruce_pag_conv=pd.merge(pagos_conv_resumen,gestion_asesor_cuotas,on=['IDENTIFICACION'],how='left')

# %% [markdown]
# ## UNIR LOS PAGOS

# %%
pagos=[cruce_pag_cuot,cruce_pag_corr]
total_pagos=pd.concat(pagos)

# %%
total_pagos.head()
# Out:
#   IDENTIFICACION  ID_FACTURA  VALOR_INFRACCION          FECHA_PAGO  DIA_PAGO  \
# 0     0917744229     5309823             36.63 2018-09-01 12:47:30         1
# 1     0924144579     3346334            112.50 2018-09-01 10:20:59         1
# 2     0924144579     3384000            112.50 2018-09-01 10:20:59         1
# 3     0924144579     3447021            112.50 2018-09-01 10:20:59         1
# 4     0924144579     3704949            112.50 2018-09-01 10:20:59         1
#
#     TIPO  DIAS_MORA
# 0  CUOTA         40
# 1  CUOTA        473
# 2  CUOTA        465
# 3  CUOTA        450
# 4  CUOTA        407

# %%
def honorarios(base):
    tipo=base['TIPO']
    mora=base['DIAS_MORA']
    valor=base['VALOR_INFRACCION']
    if tipo=='CONVENIO':
        return valor*0.035
    if tipo=='CUOTA'and mora>180:
        return valor*0.05
    if mora<61:
        return valor*0.02
    if mora<181:
        return valor*0.04
    if mora<361:
        return valor*0.05
    if mora>360:
        return valor*0.06
    return 0.0

# %%
total_pagos['HONORARIOS']=total_pagos.apply(honorarios,axis=1)
total_pagos.head()
# Out:
#   IDENTIFICACION  ID_FACTURA  VALOR_INFRACCION          FECHA_PAGO  DIA_PAGO  \
# 0     0917744229     5309823             36.63 2018-09-01 12:47:30         1
# 1     0924144579     3346334            112.50 2018-09-01 10:20:59         1
# 2     0924144579     3384000            112.50 2018-09-01 10:20:59         1
# 3     0924144579     3447021            112.50 2018-09-01 10:20:59         1
# 4     0924144579     3704949            112.50 2018-09-01 10:20:59         1
#
#     TIPO  DIAS_MORA  HONORARIOS
# 0  CUOTA         40      0.7326
# 1  CUOTA        473      5.6250
# 2  CUOTA        465      5.6250
# 3  CUOTA        450      5.6250
# 4  CUOTA        407      5.6250

# %% [markdown]
# ## CRUCE CON GESTIONES

# %%
cruce_honorario=pd.merge(total_pagos,total_gestiones,on=['IDENTIFICACION'],how='left')

# %%
cruce_honorario.head()
# Out:
#   IDENTIFICACION  ID_FACTURA  VALOR_INFRACCION          FECHA_PAGO  DIA_PAGO  \
# 0     0917744229     5309823             36.63 2018-09-01 12:47:30         1
# 1     0924144579     3346334            112.50 2018-09-01 10:20:59         1
# 2     0924144579     3384000            112.50 2018-09-01 10:20:59         1
# 3     0924144579     3447021            112.50 2018-09-01 10:20:59         1
# 4     0924144579     3704949            112.50 2018-09-01 10:20:59         1
#
#     TIPO  DIAS_MORA  HONORARIOS COD_AGENTE  FECHA_GESTION CONTACTO_GESTIONO  \
# 0  CUOTA         40      0.7326     D05554            1.0           TITULAR
# 1  CUOTA        473      5.6250     D05554            1.0           TITULAR
# 2  CUOTA        465      5.6250     D05554            1.0           TITULAR
# 3  CUOTA        450      5.6250     D05554            1.0           TITULAR
# 4  CUOTA        407      5.6250     D05554            1.0           TITULAR
#
#   ACCION_REALIZADA RESPUESTA_OBTENIDA NUMERO_GESTION
# 0       ENVIAR IVR       CONTESTO IVR     0996244591
# 1       ENVIAR IVR       CONTESTO IVR     0982149987
# 2       ENVIAR IVR       CONTESTO IVR     0982149987
# 3       ENVIAR IVR       CONTESTO IVR     0982149987
# 4       ENVIAR IVR       CONTESTO IVR     0982149987

# %%
def validar(base):
    dia_pago=base['DIA_PAGO']
    dia_gestion=base['FECHA_GESTION']
    if dia_gestion<=dia_pago:
        return 'SI'
    return 'NO'

# %%
cruce_honorario['VALIDO']=cruce_honorario.apply(validar,axis=1)
cruce_honorario.head()
# Out:
#   IDENTIFICACION  ID_FACTURA  VALOR_INFRACCION          FECHA_PAGO  DIA_PAGO  \
# 0     0917744229     5309823             36.63 2018-09-01 12:47:30         1
# 1     0924144579     3346334            112.50 2018-09-01 10:20:59         1
# 2     0924144579     3384000            112.50 2018-09-01 10:20:59         1
# 3     0924144579     3447021            112.50 2018-09-01 10:20:59         1
# 4     0924144579     3704949            112.50 2018-09-01 10:20:59         1
#
#     TIPO  DIAS_MORA  HONORARIOS COD_AGENTE  FECHA_GESTION CONTACTO_GESTIONO  \
# 0  CUOTA         40      0.7326     D05554            1.0           TITULAR
# 1  CUOTA        473      5.6250     D05554            1.0           TITULAR
# 2  CUOTA        465      5.6250     D05554            1.0           TITULAR
# 3  CUOTA        450      5.6250     D05554            1.0           TITULAR
# 4  CUOTA        407      5.6250     D05554            1.0           TITULAR
#
#   ACCION_REALIZADA RESPUESTA_OBTENIDA NUMERO_GESTION VALIDO
# 0       ENVIAR IVR       CONTESTO IVR     0996244591     SI
# 1       ENVIAR IVR       CONTESTO IVR     0982149987     SI
# 2       ENVIAR IVR       CONTESTO IVR     0982149987     SI
# 3       ENVIAR IVR       CONTESTO IVR     0982149987     SI
# 4       ENVIAR IVR       CONTESTO IVR     0982149987     SI

# %%
cruce_pag_conv['HONORARIOS']=cruce_pag_conv.apply(honorarios,axis=1)
cruce_pag_conv.head()
cruce_pag_conv['VALIDO']=cruce_pag_conv.apply(validar,axis=1)
cruce_pag_conv.head()
# Out:
#   IDENTIFICACION  ID_FACTURA  VALOR_INFRACCION FECHA_PAGO  DIA_PAGO      TIPO  \
# 0     0911992774      292221              30.0 2018-09-01         1  CONVENIO
# 1     0911992774      292221              30.0 2018-09-01         1  CONVENIO
# 2     0918876715      267479              65.8 2018-09-01         1  CONVENIO
# 3     0918876715      267479              65.8 2018-09-01         1  CONVENIO
# 4     0918876715      267479              65.8 2018-09-01         1  CONVENIO
#
#    DIAS_MORA COD_AGENTE  FECHA_GESTION CONTACTO_GESTIONO ACCION_REALIZADA  \
# 0          3        NaN            NaN               NaN              NaN
# 1          2        NaN            NaN               NaN              NaN
# 2          4        NaN            NaN               NaN              NaN
# 3          6        NaN            NaN               NaN              NaN
# 4          1        NaN            NaN               NaN              NaN
#
#   RESPUESTA_OBTENIDA NUMERO_GESTION  HONORARIOS VALIDO
# 0                NaN            NaN       1.050     NO
# 1                NaN            NaN       1.050     NO
# 2                NaN            NaN       2.303     NO
# 3                NaN            NaN       2.303     NO
# 4                NaN            NaN       2.303     NO

# %%
pagos_total=[cruce_honorario,cruce_pag_conv]
total_pagos_all=pd.concat(pagos_total)
# Out:
# c:\users\michael\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %% [markdown]
# ## HONORARIOS VALIDOS

# %%
print(total_pagos_all[total_pagos_all['VALIDO']=='SI'].groupby('TIPO').agg({'VALOR_INFRACCION':'sum','HONORARIOS':'sum'}))
print(total_pagos_all[total_pagos_all['VALIDO']=='SI'].groupby('TIPO').agg({'VALOR_INFRACCION':'sum','HONORARIOS':'sum'}).sum())
# Out:
#            VALOR_INFRACCION  HONORARIOS
# TIPO
# CONVENIO           11366.86    397.8401
# CORRIENTE         164836.88   6249.7408
# CUOTA              81586.23   3599.5963
# MENORES           137918.30   4788.9925
# VALOR_INFRACCION    395708.2700
# HONORARIOS           15036.1697
# dtype: float64

# %%
total_pagos_all[total_pagos_all['VALIDO']=='SI'].groupby('TIPO').agg({'VALOR_INFRACCION':'sum','HONORARIOS':'sum'}).plot.line()

# %% [markdown]
# ## HONORARIOS TOTALES

# %%
print(total_pagos_all.groupby('TIPO').agg({'VALOR_INFRACCION':'sum','HONORARIOS':'sum'}))
print(total_pagos_all.groupby('TIPO').agg({'VALOR_INFRACCION':'sum','HONORARIOS':'sum'}).sum())
# Out:
#            VALOR_INFRACCION  HONORARIOS
# TIPO
# CONVENIO           67062.39  2347.18365
# CORRIENTE         176054.53  6655.06980
# CUOTA              86794.67  3825.06680
# MENORES           161874.20  5517.31900
# VALOR_INFRACCION    491785.79000
# HONORARIOS           18344.63925
# dtype: float64

# %% [markdown]
# ## HONORARIOS NO VALIDOS

# %%
print(total_pagos_all[total_pagos_all['VALIDO']=='NO'].groupby('TIPO').agg({'VALOR_INFRACCION':'sum','HONORARIOS':'sum'}))
print(total_pagos_all[total_pagos_all['VALIDO']=='NO'].groupby('TIPO').agg({'VALOR_INFRACCION':'sum','HONORARIOS':'sum'}).sum())
# Out:
#            VALOR_INFRACCION  HONORARIOS
# TIPO
# CONVENIO           55695.53  1949.34355
# CORRIENTE          11217.65   405.32900
# CUOTA               5208.44   225.47050
# MENORES            23955.90   728.32650
# VALOR_INFRACCION    96077.52000
# HONORARIOS           3308.46955
# dtype: float64

# %%
nuevo_archivo='ANALISIS DE PAGOS.xlsx'
writer = pd.ExcelWriter(nuevo_archivo, engine='xlsxwriter')
total_pagos_all.to_excel(writer, sheet_name='GESTION TOTAL')
worksheet = writer.sheets['GESTION TOTAL']
writer.save()

# %%
nuevo_archivo='GESTION ASESOR.xlsx'
writer = pd.ExcelWriter(nuevo_archivo, engine='xlsxwriter')
gestion_asesor.to_excel(writer, sheet_name='GESTION TOTAL')
worksheet = writer.sheets['GESTION TOTAL']
writer.save()
