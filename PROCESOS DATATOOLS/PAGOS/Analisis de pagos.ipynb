# %%
import pandas as pd
import MySQLdb
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
#%matplotlib notebook

# %%
pago_corr={
    'ruta':'..\..\..\BASES DATATOOLS\PAGOS\\2019\\ABRIL\Sitema de cobro 23042019.xlsx',
    'hoja':'PAGOS_CORRIENTE',
    'cartera':'CORRIENTE',
    'identificador':'IDENTIFICACION'
}

pago_cuota={
    'ruta':'..\..\..\BASES DATATOOLS\PAGOS\\2019\\ABRIL\\Sitema de cobro 23042019.xlsx',
    'hoja':'PAGOS_CUOTACERO',
    'cartera':'CONVENIO',
    'identificador':'ID'
}

pago_conv={
    'ruta':'..\..\..\BASES DATATOOLS\PAGOS\\2019\\ABRIL\\Sitema de cobro 23042019.xlsx',
    'hoja':'PAGOS_CONVENIOS',
    'cartera':'CONVENIO',
    'identificador':'ID'
}

# %%
pagos_corr=pd.read_excel(open(pago_corr['ruta'],'rb'), sheet_name=pago_corr['hoja'], dtype={pago_corr['identificador']: str})
pago_cuota=pd.read_excel(open(pago_cuota['ruta'],'rb'), sheet_name=pago_cuota['hoja'], dtype={pago_cuota['identificador']: str})
pagos_conv=pd.read_excel(open(pago_conv['ruta'],'rb'), sheet_name=pago_conv['hoja'], dtype={pago_conv['identificador']: str})

# %%
pagos_corr['tipo']='CORRIENTE'
pagos_corr.head()
# Out:
#   IDENTIFICACION  ID_FACTURA  VALOR_INFRACCION FECHA_PAGO  \
# 0      910625698     5781708              57.9 2019-04-01
# 1      910625698     4605960              19.3 2019-04-01
# 2     1304090184     6235102              59.1 2019-04-01
# 3      917470908     6220499             118.2 2019-04-01
# 4      952393593     6262859             394.0 2019-04-01
#
#                            CASA       tipo
# 0  SISTEMA DE COBRO DEL ECUADOR  CORRIENTE
# 1  SISTEMA DE COBRO DEL ECUADOR  CORRIENTE
# 2  SISTEMA DE COBRO DEL ECUADOR  CORRIENTE
# 3  SISTEMA DE COBRO DEL ECUADOR  CORRIENTE
# 4  SISTEMA DE COBRO DEL ECUADOR  CORRIENTE

# %%
por_fecha = pd.pivot_table(pagos_corr,values=['VALOR_INFRACCION'],index=['FECHA_PAGO'],aggfunc=np.sum,margins=True)

# %%
por_fecha[:-1].plot(kind='line')

# %%
acumulado=por_fecha.cumsum()

# %%
acumulado[:-1].plot(kind='line')

# %%
por_fecha[:-1].plot(kind='line')

# %%
acumulado=por_fecha.cumsum()
acumulado[:-1].plot(kind='line')
